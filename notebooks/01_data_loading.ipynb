# %%
# 01_data_loading.ipynb
# Load and inspect the raw dataset
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {"language": "markdown"},
      "source": [
        "# 01 — Data Loading\n",
        "Load and inspect the raw plant health dataset."
      ]
    },
    {
      "cell_type": "code",
      "metadata": {"language": "python"},
      "source": [
        "import pandas as pd\n",
        "import numpy as np\n",
        "# Load the raw dataset\n",
        "df = pd.read_csv('../data/raw_dataset.csv')\n",
        "df.head()"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {"language": "python"},
      "source": [
        "# Shape of the dataset\n",
        "df.shape"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {"language": "python"},
      "source": [
        "# Data types and info\n",
        "df.info()"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {"language": "python"},
      "source": [
        "# Descriptive statistics\n",
        "df.describe()"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {"language": "python"},
      "source": [
        "# Check for missing values\n",
        "df.isnull().sum()"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {"language": "python"},
      "source": [
        "# Check class distribution (if Health_Status exists)\n",
        "if 'Health_Status' in df.columns:\n    print(df['Health_Status'].value_counts())\nelse:\n    print('Health_Status column not found.')"
      ]
    }
  ]
}
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'language': 'markdown'},
#    'source': ['# 01 — Data Loading\n',
#     'Load and inspect the raw plant health dataset.']},
#   {'cell_type': 'code',
#    'metadata': {'language': 'python'},
#    'source': ['import pandas as pd\n',
#     'import numpy as np\n',
#     '# Load the raw dataset\n',
#     "df = pd.read_csv('../data/raw_dataset.csv')\n",
#     'df.head()']},
#   {'cell_type': 'code',
#    'metadata': {'language': 'python'},
#    'source': ['# Shape of the dataset\n', 'df.shape']},
#   {'cell_type': 'code',
#    'metadata': {'language': 'python'},
#    'source': ['# Data types and info\n', 'df.info()']},
#   {'cell_type': 'code',
#    'metadata': {'language': 'python'},
#    'source': ['# Descriptive statistics\n', 'df.describe()']},
#   {'cell_type': 'code',
#    'metadata': {'language': 'python'},
#    'source': ['# Check for missing values\n', 'df.isnull().sum()']},
#   {'cell_type': 'code',
#    'metadata': {'language': 'python'},
#    'source': ['# Check class distribution (if Health_Status exists)\n',
#     "if 'Health_Status' in df.columns:\n    print(df['Health_Status'].value_counts())\nelse:\n    print('Health_Status column not found.')"]}]}
